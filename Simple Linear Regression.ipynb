# %%
import pandas as pd
dataf = pd.read_csv("E:bmi.csv")
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 0 to 740
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       741 non-null    int64
#  1   Height    741 non-null    float64
#  2   Weight    741 non-null    float64
#  3   Bmi       741 non-null    float64
#  4   BmiClass  741 non-null    object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 29.1+ KB

# %%
dataf.describe()
# Out:
#               Age      Height      Weight         Bmi
# count  741.000000  741.000000  741.000000  741.000000
# mean    31.618084    1.709427   78.412497   26.365427
# std     11.655466    0.085974   32.254547    9.223191
# min     15.000000    1.460000   25.900000   12.150497
# 25%     22.000000    1.670000   63.000000   22.129740
# 50%     29.000000    1.721000   72.900000   24.132412
# 75%     40.000000    1.751000   83.300000   27.249306
# max     61.000000    2.070000  270.000000   66.301350

# %%
dataf = dataf[['Height','Weight']]
dataf
# Out:
#      Height  Weight
# 0      1.85  109.30
# 1      1.71   79.02
# 2      1.55   74.70
# 3      1.46   35.90
# 4      1.58   97.10
# ..      ...     ...
# 736    1.86   95.70
# 737    1.91  106.90
# 738    1.82   88.40
# 739    1.88   98.50
# 740    1.93  109.90
#
# [741 rows x 2 columns]

# %%
X = dataf['Height']
y = dataf['Weight']

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.xlabel("Height")
plt.ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
from sklearn.model_selection import train_test_split
X_test, X_train, y_test, y_train = train_test_split(X, y, test_size = 0.4, random_state = 30)

# %%
X_train
# Out:
# 269    1.740
# 683    1.650
# 436    1.752
# 584    1.640
# 152    1.740
#        ...
# 13     1.470
# 213    1.600
# 524    1.710
# 221    1.740
# 377    1.760
# Name: Height, Length: 297, dtype: float64

# %%
#coverting 1D to 2D array
import numpy as np
X_train = np.array(X_train).reshape(-1,1)
X_train
X_test = np.array(X_test).reshape(-1,1)
X_test
# Out:
# array([[1.705 ],
#        [1.52  ],
#        [1.74  ],
#        [1.75  ],
#        [1.75  ],
#        [1.65  ],
#        [1.742 ],
#        [1.825 ],
#        [1.74  ],
#        [1.47  ],
#        [1.8   ],
#        [1.7298],
#        [1.72  ],
#        [1.78  ],
#        [1.65  ],
#        [1.72  ],
#        [1.62  ],
#        [1.74  ],
#        [1.68  ],
#        [1.73  ],
#        [1.72  ],
#        [1.76  ],
#        [1.77  ],
#        [1.73  ],
#        [1.71  ],
#        [1.72  ],
#        [1.76  ],
#        [1.74  ],
#        [1.68  ],
#        [1.74  ],
#        [1.78  ],
#        [1.9   ],
#        [1.82  ],
#        [1.8   ],
#        [1.71  ],
#        [1.76  ],
#        [1.7   ],
#        [1.8   ],
#        [1.6   ],
#        [1.74  ],
#        [1.76  ],
#        [1.729 ],
#        [1.74  ],
#        [1.738 ],
#        [1.81  ],
#        [1.76  ],
#        [1.74  ],
#        [1.762 ],
#        [1.75  ],
#        [1.68  ],
#        [1.605 ],
#        [1.65  ],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
# taining the model
rs = LinearRegression()
rs.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#y intercept (y = mx +c)
c = rs.intercept_
c
# Out:
# -312.2080289542655

# %%
# coefficient

m= rs.coef_
m
# Out:
# array([227.42181722])

# %%
# making prediction

prediction = m*X_train+c
prediction.flatten()
# Out:
# array([ 83.50593301,  63.03796946,  86.23499482,  60.76375129,
#         83.50593301,  88.05436936,  92.6028057 ,  74.40906033,
#         58.48953312,  96.92382023,  83.50593301,  85.78015119,
#         85.78015119,  83.50593301,  92.6028057 ,  81.23171484,
#         78.95749667,  85.78015119,  94.87702388,  90.32858753,
#         90.32858753,  92.6028057 ,  63.03796946,  94.87702388,
#         74.40906033,  67.58640581,  78.95749667,  78.95749667,
#         33.47313323,  60.76375129,  58.48953312,  83.50593301,
#         70.77031125,  92.6028057 ,  40.29578774,  90.32858753,
#         69.86062398,  69.86062398,  26.65047871,  86.46241664,
#        101.69967839,  92.6028057 ,  63.03796946,  81.23171484,
#         69.86062398,  44.84422409,  47.11844226,  58.48953312,
#         92.6028057 ,  85.73466682,  85.78015119,  92.6028057 ,
#         81.00429303,  74.40906033,  83.2785112 ,  65.31218764,
#         76.6832785 ,  72.13484215,  85.78015119,  74.40906033,
# ...

# %%
pred_test = rs.predict(X_test)
pred_test
# Out:
# array([ 75.54616941,  33.47313323,  83.50593301,  85.78015119,
#         85.78015119,  63.03796946,  83.96077665, 102.83678748,
#         83.50593301,  22.10204236,  97.15124205,  81.18623048,
#         78.95749667,  92.6028057 ,  63.03796946,  78.95749667,
#         56.21531495,  83.50593301,  69.86062398,  81.23171484,
#         78.95749667,  88.05436936,  90.32858753,  81.23171484,
#         76.6832785 ,  78.95749667,  88.05436936,  83.50593301,
#         69.86062398,  83.50593301,  92.6028057 , 119.89342377,
#        101.69967839,  97.15124205,  76.6832785 ,  88.05436936,
#         74.40906033,  97.15124205,  51.6668786 ,  83.50593301,
#         88.05436936,  81.00429303,  83.50593301,  83.05108938,
#         99.42546022,  88.05436936,  83.50593301,  88.50921299,
#         85.78015119,  69.86062398,  52.80398769,  63.03796946,
#         83.50593301,  78.95749667,  49.39266043,  88.50921299,
#         72.13484215,  69.86062398,  88.05436936,  90.78343117,
# ...

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test,pred_test, color='red')
